# %% [markdown]
# <a href="https://colab.research.google.com/github/obeabi/JumiaReviewScrapper/blob/main/MiniScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# doing necessary imports
import logging
from datetime import datetime
from flask import Flask, render_template, request,jsonify
# from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq, Request
#import pymongo

app = Flask(__name__)  # initialising the flask app with the name 'app'
# Configure logging to write to a text file named 'logfile.txt'
logging.basicConfig(level=logging.INFO, filename='logfile.txt', filemode='a', format='%(asctime)s - %(levelname)s - %(message)s')

lg = logging.getLogger(__name__)
today_date = datetime.today().strftime('%Y-%m-%d')
# Specify your browser's user agent string
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"

# %%
try:
  searchString ='bag'
  searchString = searchString.replace(' ', '')
  searchString
  current_page = 1
  reviews = []
  total_pages = 2
  url = "https://www.jumia.com.ng"
  filename = searchString + "_" + today_date + ".csv"
  fw       = open(filename, "a") # creating a local file to save the details
  headers  = "Product, Customer Name, Rating, Heading, Comment \n" # providing the heading of the columns
  fw.write(headers)  # writing first the headers to file
  #table = db[searchString] # creating a collection with the same name as search string. Tables and Collections are analogous.
  if not True:
    pass
  else:
    while current_page <= total_pages:
      page_url = "https://www.jumia.com.ng/catalog/?q=" + searchString + "&page="+ str(current_page)# preparing the URL to search the product on  Jumia
      lg.info("Page %s is available", current_page)  # Log the message with the page number
      # Create a Request object with the URL and headers
      url_page = requests.get(page_url, headers={'User-Agent': user_agent})
      # Read the content of the response
      page_html = bs(url_page.content , "html.parser") # parsing the webpage as HTML
      bigboxes = page_html.findAll("article", {"class": "prd _fb col c-prd"}) # seacrhing for appropriate tag to redirect to the product link
      del bigboxes[0:3] # the first 3 members of the list do not contain relevant information, hence deleting them.

      for box in bigboxes:
        productLink = url + box.findAll('a')[1]['href']
        prodRes     = requests.get(productLink, headers={'User-Agent': user_agent})  # getting the product page from server
        prod_html   = bs(prodRes.text, features="html.parser")  # parsing the product page as HTML
        reveiw_section = prod_html.find_all("section", {"class": "card aim -mtm"})

        try:
          reveiw_section       = prod_html.find_all("section", {"class": "card aim -mtm"})
          productAllReviewLink = "https://www.jumia.com.ng" + reveiw_section[0].find('a')['href']
          revRes               = requests.get(productAllReviewLink , headers={'User-Agent': user_agent})  # getting the review_url for an individual page
          review_html          = bs(revRes.text,features="html.parser")  # parsing the review page as HTML
          commentboxes         = review_html .find_all('article', {'class' : "-pvs -hr _bet"})
        except:
          commentboxes = prod_html .find_all('article', {'class' : "-pvs -hr _bet"})

        for commentbox in commentboxes:
          try:
            name = commentbox.find_all('div')[2].div.find_all('span')[1].text
            name = name[3:]
          except:
            name = 'No Name'
            lg.info("No name is available")

          try:
            rating =commentbox.div.text
            rating = rating[0]
          except:
            rating ='No Rating'
            lg.info("No rating is available")

          try:
            commentDate = commentbox.find_all('div')[2].div.find_all('span')[0].text
          except:
            commentDate = 'No Comment Date'
            lg.info("No comment date is available")

          try:
            commentHead = commentbox.h3.text.lower()
          except:
            commentHead = 'No Comment Head'
            lg.info("No comment head is available")

          try:
            custComment = commentbox.p.text
          except:
            custComment = 'No Customer Comment'
            lg.info("No customer comment is available")

          fw.write(searchString+","+name.replace(",", ":")+","+rating + "," + commentHead.replace(",", ":") + "," + custComment.replace(",", ":") + "\n")
          mydict = {"Product": searchString, "Name": name, "Rating": rating, "CommentHead": commentHead,"Comment": custComment} # saving that detail to a dictionary
          #x = table.insert_one(mydict) #insertig the dictionary containing the rview comments to the collection
          reviews.append(mydict) #  appending the comments to the review list
      current_page += 1
except Exception as e:
  print("Something is wrong!")
  lg.error("An error occurred: {}".format(str(e)))

# %%
reviews
# Out:
# [{'Product': 'bag',
#   'Name': 'nwosu',
#   'Rating': '2',
#   'CommentHead': 'rubbish',
#   'Comment': 'not good at all'},
#  {'Product': 'bag',
#   'Name': 'Prechi',
#   'Rating': '1',
#   'CommentHead': 'the bag is not what i think of ',
#   'Comment': ' The zip is not good\nThe bag is not strong '},
#  {'Product': 'bag',
#   'Name': 'Tari',
#   'Rating': '1',
#   'CommentHead': "i don't like it",
#   'Comment': 'Very poor quality, the zip got spoiled after a day use'},
#  {'Product': 'bag',
#   'Name': 'Blessing',
#   'Rating': '1',
#   'CommentHead': 'poor quality',
#   'Comment': "The zipper got damaged the first day I used the bag. It's not solid. It's too light "},
#  {'Product': 'bag',
#   'Name': 'Chidiebere',
#   'Rating': '2',
#   'CommentHead': "i don't like it",
#   'Comment': 'The zip broke on the first day, fake material, the bag is not strong'},
#  {'Product': 'bag',
#   'Name': 'Jay',
#   'Rating': '5',
#   'CommentHead': 'it’s good',
#   'Comment': 'But work more on the zips'},
#  {'Product': 'bag',
#   'Name': 'Angel',
#   'Rating': '1',
#   'CommentHead': 'horrible ',
#   'Comment': 'Material is so week the bag tears easily and is way smaller and way lighter zip broke immediately '},
#  {'Product': 'bag',
#   'Name': 'Kpokpogri Sonia',
#   'Rating': '4',
#   'CommentHead': 'the bag is strong n cute',
#   'Comment': 'Work on the zip it’s not strong '},
#  {'Product': 'bag',
#   'Name': 'Adeyinka Temitope ',
#   'Rating': '3',
#   'CommentHead': 'good material ',
#   'Comment': 'the material was perfect '},
#  {'Product': 'bag',
#   'Name': 'christiana',
#   'Rating': '3',
#   'CommentHead': 'the zip ',
#   'Comment': 'The zip started breaking off the first time I used it......the material is too light'},
#  {'Product': 'bag',
#   'Name': 'Hauwa Suka',
#   'Rating': '5',
#   'CommentHead': 'good material ',
#   'Comment': 'Looks elegant bcs of the material on the bag'},
#  {'Product': 'bag',
#   'Name': 'COLLINS',
#   'Rating': '4',
#   'CommentHead': 'good ',
#   'Comment': 'The quality of the bag is ok,'},
#  {'Product': 'bag',
#   'Name': 'Ada',
#   'Rating': '5',
#   'CommentHead': 'lovely bag',
#   'Comment': 'Really love it'},
#  {'Product': 'bag',
#   'Name': 'Blessing',
#   'Rating': '5',
#   'CommentHead': 'the quality is good',
#   'Comment': 'I love the bag quality, the finishing and design.'},
#  {'Product': 'bag',
#   'Name': 'Christabel Daniel',
#   'Rating': '5',
#   'CommentHead': 'a good rider',
#   'Comment': 'Only the Zip. The Rider is a good person unlike others '},
#  {'Product': 'bag',
#   'Name': 'Teemah',
#   'Rating': '4',
#   'CommentHead': 'i love it',
#   'Comment': 'It actually what I want but I thought the little doll will have fur lols it actually a nice bag'},
#  {'Product': 'bag',
#   'Name': 'The Bane Of Your Existence',
#   'Rating': '3',
#   'CommentHead': 'it’s okay',
#   'Comment': 'The Bag is okay and all but it’s smaller then expected'},
#  {'Product': 'bag',
#   'Name': 'Oladapo Salu',
#   'Rating': '4',
#   'CommentHead': 'just as expected',
#   'Comment': 'It can be bigger'},
#  {'Product': 'bag',
#   'Name': 'Tamilore Fatile',
#   'Rating': '5',
#   'CommentHead': 'nice product ',
#   'Comment': 'I like the product '},
#  {'Product': 'bag',
#   'Name': 'LoCo ',
#   'Rating': '2',
#   'CommentHead': 'the stitches are loose',
#   'Comment': 'It started loosing few days after I got it, it’s smaller than it looks.'},
#  {'Product': 'bag',
#   'Name': 'Chibueze',
#   'Rating': '2',
#   'CommentHead': 'poor',
#   'Comment': 'Poor quality. False advertising. The bag is really smaller. Smaller than you imagine'},
#  {'Product': 'bag',
#   'Name': 'John Godwin',
#   'Rating': '5',
#   'CommentHead': 'love it',
#   'Comment': 'Good\n'},
#  {'Product': 'bag',
#   'Name': 'Anuoluwa',
#   'Rating': '1',
#   'CommentHead': 'very low quality',
#   'Comment': 'The quality of material is very poor, should not be called a laptop bag because it is not well padded. It already showing sign of tearing after carrying a small laptop in it 3 times.'},
#  {'Product': 'bag',
#   'Name': 'Emmanuel',
#   'Rating': '2',
#   'CommentHead': 're',
#   'Comment': 'The material should be improved on and the lock should be firmly fixed'},
#  {'Product': 'bag',
#   'Name': 'Taiwo',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': "It secured and it's a portable bag as well"},
#  {'Product': 'bag',
#   'Name': 'Lois',
#   'Rating': '3',
#   'CommentHead': "not too bad, but the quality isn't good enough ????",
#   'Comment': "Not too bad, but the quality isn't as good enough ????"},
#  {'Product': 'bag',
#   'Name': 'Abimbola',
#   'Rating': '5',
#   'CommentHead': 'my 5 and 6. wink.',
#   'Comment': "I can't go anywhere without this bag!"},
#  {'Product': 'bag',
#   'Name': 'Oladapo',
#   'Rating': '2',
#   'CommentHead': "don't like it",
#   'Comment': 'It not strong all the ziplock has spoiled withing 4month  I bought it'},
#  {'Product': 'bag',
#   'Name': 'Efe Bishop',
#   'Rating': '1',
#   'CommentHead': 'very poor',
#   'Comment': 'The bag falls way below standard. The size is way smaller than the way it appears on the site. The person I helped to order it almost rejected it.'},
#  {'Product': 'bag',
#   'Name': 'Abraham',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'Although it was a bit smaller than I expected, it is quite durable in terms of the quality. Moreso, it is serving me quite well as a laptop bag.'},
#  {'Product': 'bag',
#   'Name': 'Alee',
#   'Rating': '1',
#   'CommentHead': 'the quality/ material used is not good.  ',
#   'Comment': 'Use a quality and strong material for sake of durability '},
#  {'Product': 'bag',
#   'Name': 'AUWWAL',
#   'Rating': '5',
#   'CommentHead': 'excellent',
#   'Comment': 'LOVE  IT. WHAT I NEED TO FOR TRAVEL'},
#  {'Product': 'bag',
#   'Name': 'Omoakin',
#   'Rating': '3',
#   'CommentHead': '..',
#   'Comment': "I wasn't expecting much at that price. I only thought I should clear my doubt"},
#  {'Product': 'bag',
#   'Name': 'Kingsley',
#   'Rating': '1',
#   'CommentHead': "i don't like it",
#   'Comment': 'It is not as it is in the picture\nLow quality bag\nEverything bad\nI am not happy at all'},
#  {'Product': 'bag',
#   'Name': 'Gradient036 ',
#   'Rating': '4',
#   'CommentHead': 'nice ',
#   'Comment': 'Nice and light for the low budget. Don’t use to carry heavyweight. The material doesn’t last that long if heavy objects are carried with it '},
#  {'Product': 'bag',
#   'Name': 'Ejimofor',
#   'Rating': '1',
#   'CommentHead': 'poor',
#   'Comment': 'Very poor quality '},
#  {'Product': 'bag',
#   'Name': 'Chidera Osuji',
#   'Rating': '1',
#   'CommentHead': 'poor quality ',
#   'Comment': 'The size of the product as seen on the image is not the size in reality. And the quality is bad, not fair but bad. But I guess that’s why it is this cheap.'},
#  {'Product': 'bag',
#   'Name': 'Chinyere',
#   'Rating': '3',
#   'CommentHead': 'inferior material',
#   'Comment': 'The material was too light and did not look the same as the one in the picture on the app'},
#  {'Product': 'bag',
#   'Name': 'OLUWASEYE OLUSEGUN',
#   'Rating': '4',
#   'CommentHead': 'its okay ',
#   'Comment': 'A better quality leather '},
#  {'Product': 'bag',
#   'Name': 'Ekenedilichukwu Ekeh',
#   'Rating': '4',
#   'CommentHead': 'perfect, only it has a fragile zip. ',
#   'Comment': 'It’s compartments allow you to organize your stuff. It’s rather small, but nothing you’d notice. Texture is great but the zipper simply isn’t. '},
#  {'Product': 'bag',
#   'Name': 'EMMANUEL',
#   'Rating': '1',
#   'CommentHead': 'spoilt',
#   'Comment': 'The bag zips were all damaged, the bag was not as expected.'},
#  {'Product': 'bag',
#   'Name': 'Iliya Mele',
#   'Rating': '5',
#   'CommentHead': 'casual crossbody bag',
#   'Comment': 'Very portable, strong and convenient '},
#  {'Product': 'bag',
#   'Name': 'Sochima',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Was exactly what I saw and ordered, thank you.'},
#  {'Product': 'bag',
#   'Name': 'Oluwatobiloba',
#   'Rating': '1',
#   'CommentHead': 'terrible',
#   'Comment': 'Was lucky to use it for just 1 week and all the zippers broke.\nThat is how this story ended'},
#  {'Product': 'bag',
#   'Name': 'Emmanuel',
#   'Rating': '5',
#   'CommentHead': 'l like it',
#   'Comment': 'It so portable '},
#  {'Product': 'bag',
#   'Name': 'Ajayi',
#   'Rating': '1',
#   'CommentHead': 'the zip',
#   'Comment': "The zip spoil immdiately i open the bag,this bag is nit what i expected it's really bad"},
#  {'Product': 'bag',
#   'Name': 'Kelvn Ekhator',
#   'Rating': '2',
#   'CommentHead': 'the zipper',
#   'Comment': 'The zipper is wrongly made '},
#  {'Product': 'bag',
#   'Name': 'Johnson',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'Good Nice doing business with you'},
#  {'Product': 'bag',
#   'Name': 'Seyi',
#   'Rating': '1',
#   'CommentHead': 'not good enough ',
#   'Comment': 'Add quality to the product\n'},
#  {'Product': 'bag',
#   'Name': 'adebola',
#   'Rating': '1',
#   'CommentHead': 'bad material',
#   'Comment': 'The material of the bag is bad compared to what is shown in the picture.'},
#  {'Product': 'bag',
#   'Name': 'Oluwaseun',
#   'Rating': '5',
#   'CommentHead': 'worth the price',
#   'Comment': 'Quite solid '},
#  {'Product': 'bag',
#   'Name': 'Onyema',
#   'Rating': '3',
#   'CommentHead': 'not what i expected',
#   'Comment': 'Does not look strong'},
#  {'Product': 'bag',
#   'Name': 'Adakole',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'it was okay'},
#  {'Product': 'bag',
#   'Name': 'Peter',
#   'Rating': '5',
#   'CommentHead': 'hundred percent gooo',
#   'Comment': 'The product is good'},
#  {'Product': 'bag',
#   'Name': 'Onuoha',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'Its almost 1year+ ve been using it, its okay.'},
#  {'Product': 'bag',
#   'Name': 'Kehinde',
#   'Rating': '1',
#   'CommentHead': 'bad quality',
#   'Comment': 'The bag actually looks nice and the size is actually ok as promised but the zipper and zip quality is very bad, it all removed the first day I decided to use it, I had to change the entire zip'},
#  {'Product': 'bag',
#   'Name': 'Rafiu Karimu',
#   'Rating': '5',
#   'CommentHead': 'the quality materials ',
#   'Comment': 'Superb'},
#  {'Product': 'bag',
#   'Name': 'Abraham',
#   'Rating': '1',
#   'CommentHead': 'try',
#   'Comment': 'Improve the zips very bad and the strap holder'},
#  {'Product': 'bag',
#   'Name': 'Amos',
#   'Rating': '5',
#   'CommentHead': 'nice one',
#   'Comment': 'I love it, so nice.'},
#  {'Product': 'bag',
#   'Name': 'Michael',
#   'Rating': '4',
#   'CommentHead': 'great product',
#   'Comment': 'Great product but the strap is thin.\nLike what I got though.'},
#  {'Product': 'bag',
#   'Name': 'Juliet',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Exactly as seen'},
#  {'Product': 'bag',
#   'Name': 'Jack',
#   'Rating': '5',
#   'CommentHead': 'mr',
#   'Comment': 'Good '},
#  {'Product': 'bag',
#   'Name': 'CHISOM',
#   'Rating': '5',
#   'CommentHead': 'great ',
#   'Comment': 'A beautiful and simple bag'},
#  {'Product': 'bag',
#   'Name': 'IniAbasi',
#   'Rating': '5',
#   'CommentHead': 'great product',
#   'Comment': "I love the quality of the bag. A lot of people here are complaining about the zip, it's not that bad but one needs to be careful when using it. Overall...I love and recommend it."},
#  {'Product': 'bag',
#   'Name': 'Olalere',
#   'Rating': '3',
#   'CommentHead': 'i like it',
#   'Comment': 'Good product work more'},
#  {'Product': 'bag',
#   'Name': 'oluwadamilare',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'very good product'},
#  {'Product': 'bag',
#   'Name': 'Godswill Tamunokonbia',
#   'Rating': '5',
#   'CommentHead': 'cool',
#   'Comment': 'The bag is portable and simple. Good feel, you need one for your self. ????'},
#  {'Product': 'bag',
#   'Name': 'Kpossa',
#   'Rating': '5',
#   'CommentHead': 'good  ',
#   'Comment': 'Look nice '},
#  {'Product': 'bag',
#   'Name': 'Oluwole',
#   'Rating': '5',
#   'CommentHead': 'i love it!!!',
#   'Comment': 'Lovely brand to always recommend!!!'},
#  {'Product': 'bag',
#   'Name': 'Martins',
#   'Rating': '3',
#   'CommentHead': 'great product',
#   'Comment': 'The product is okay for the price '},
#  {'Product': 'bag',
#   'Name': 'Samson Babajide owoyemi',
#   'Rating': '5',
#   'CommentHead': 'not bad for the price ',
#   'Comment': 'Neat and nice'},
#  {'Product': 'bag',
#   'Name': 'Confidence',
#   'Rating': '3',
#   'CommentHead': 'durability',
#   'Comment': 'It not strong and not big enough '},
#  {'Product': 'bag',
#   'Name': 'Nobel',
#   'Rating': '4',
#   'CommentHead': "comfortable but doesn't last long",
#   'Comment': 'The only thing keeping it from getting a perfect rating is the build quality.'},
#  {'Product': 'bag',
#   'Name': 'Alex',
#   'Rating': '3',
#   'CommentHead': 'i like it',
#   'Comment': 'I saw and like it because my colleague uses same'},
#  {'Product': 'bag',
#   'Name': 'Oladipupo',
#   'Rating': '1',
#   'CommentHead': 'i am not happy',
#   'Comment': 'not a quality bag'},
#  {'Product': 'bag',
#   'Name': 'Abraham Onipede',
#   'Rating': '2',
#   'CommentHead': 'low quality ',
#   'Comment': 'The older versions are way more better than the new ones being produced .'},
#  {'Product': 'bag',
#   'Name': 'Marcus',
#   'Rating': '4',
#   'CommentHead': 'good product',
#   'Comment': 'It light and smooth'},
#  {'Product': 'bag',
#   'Name': 'Jeremiah',
#   'Rating': '2',
#   'CommentHead': 'low quality',
#   'Comment': 'Not what I expected\n'},
#  {'Product': 'bag',
#   'Name': 'Ogbeni',
#   'Rating': '3',
#   'CommentHead': 'not of good quality',
#   'Comment': 'One of the zip spoilt in the space of one week usage'},
#  {'Product': 'bag',
#   'Name': 'Ann',
#   'Rating': '3',
#   'CommentHead': "i'd prefer a more sturdy bag",
#   'Comment': "I'd prefer a more sturdy bag, since it's for laptops, when I opened it, the zip was closed but the downpart had ripped open, please work more in making it thick, it's too frail."},
#  {'Product': 'bag',
#   'Name': 'Philemon',
#   'Rating': '3',
#   'CommentHead': 'i like it',
#   'Comment': 'The quality of the material is poor.'},
#  {'Product': 'bag',
#   'Name': 'Akporede',
#   'Rating': '5',
#   'CommentHead': 'just as display',
#   'Comment': 'Its worth the price'},
#  {'Product': 'bag',
#   'Name': 'Campbell Andersen',
#   'Rating': '4',
#   'CommentHead': 'campbell ',
#   'Comment': 'Very nice and fit when ever it’s use '},
#  {'Product': 'bag',
#   'Name': 'Izy',
#   'Rating': '5',
#   'CommentHead': 'great',
#   'Comment': 'Actually of the highest quality '},
#  {'Product': 'bag',
#   'Name': 'Anthony',
#   'Rating': '4',
#   'CommentHead': "it's great",
#   'Comment': 'It has served me for about 2 years now'},
#  {'Product': 'bag',
#   'Name': 'ALFRED',
#   'Rating': '3',
#   'CommentHead': "i don't like it",
#   'Comment': 'The zip is not strong at all'},
#  {'Product': 'bag',
#   'Name': 'Azeez',
#   'Rating': '2',
#   'CommentHead': 'it is too small ',
#   'Comment': 'Increase the space size of every compartment'},
#  {'Product': 'bag',
#   'Name': 'Babatunde',
#   'Rating': '4',
#   'CommentHead': 'zip',
#   'Comment': 'It almost perfect, but the zips were not that strong '},
#  {'Product': 'bag',
#   'Name': 'Victor',
#   'Rating': '1',
#   'CommentHead': 'worn out zips',
#   'Comment': "All the zips spoilt on the same day, couldn't use "},
#  {'Product': 'bag',
#   'Name': 'Meshach',
#   'Rating': '3',
#   'CommentHead': 'the zip broke off without any force',
#   'Comment': 'Its quality is fair'},
#  {'Product': 'bag',
#   'Name': 'Funmilola',
#   'Rating': '4',
#   'CommentHead': 'top-notch ',
#   'Comment': 'Very beautiful '},
#  {'Product': 'bag',
#   'Name': 'Jomo',
#   'Rating': '4',
#   'CommentHead': 'i like it, but...',
#   'Comment': "This is the 3rd time I've bought this particular bag. I love the bag, but...within a few days, a zipper will break...or the zipper handle will fall off...and I have to have it repaired, just days after I bought it!! Nice bag, but poor quality especially the zippers. Still, a bargain at this price..."},
#  {'Product': 'bag',
#   'Name': 'RAJI IDOWU',
#   'Rating': '5',
#   'CommentHead': 'mr.',
#   'Comment': 'Quality'},
#  {'Product': 'bag',
#   'Name': 'Bashar',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Very good'},
#  {'Product': 'bag',
#   'Name': 'Chidera Osegbo',
#   'Rating': '2',
#   'CommentHead': 'i don’t like the bag ',
#   'Comment': 'The bag is aba made ????????????'},
#  {'Product': 'bag',
#   'Name': 'Benita',
#   'Rating': '3',
#   'CommentHead': 'could be better',
#   'Comment': "It's good but not as I was expecting it to be "},
#  {'Product': 'bag',
#   'Name': 'that cute anonymous',
#   'Rating': '4',
#   'CommentHead': 'it came nice',
#   'Comment': "It was delivered nicely and it's what I ordered "},
#  {'Product': 'bag',
#   'Name': 'Emmanuel Isibor',
#   'Rating': '5',
#   'CommentHead': "it's a good quality bag",
#   'Comment': "It's good to carry along"},
#  {'Product': 'bag',
#   'Name': 'Akindele Taiwo',
#   'Rating': '5',
#   'CommentHead': 'good ',
#   'Comment': 'It’s worked perfectly \n'},
#  {'Product': 'bag',
#   'Name': 'Successful',
#   'Rating': '1',
#   'CommentHead': 'hmmmm',
#   'Comment': 'Nice, not what I got though'},
#  {'Product': 'bag',
#   'Name': 'Bolarinwa Samuel',
#   'Rating': '2',
#   'CommentHead': 'improve in quality ',
#   'Comment': 'low quality '},
#  {'Product': 'bag',
#   'Name': 'John favour',
#   'Rating': '3',
#   'CommentHead': 'i like it',
#   'Comment': 'Nice but not quality enough'},
#  {'Product': 'bag',
#   'Name': 'equalright',
#   'Rating': '5',
#   'CommentHead': 'my wife love it so much',
#   'Comment': 'Meet my expectation '},
#  {'Product': 'bag',
#   'Name': 'Henrrientta',
#   'Rating': '5',
#   'CommentHead': 'nice',
#   'Comment': 'Small but okay for the price '},
#  {'Product': 'bag',
#   'Name': 'Adura',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'Came exactly how I ordered it.'},
#  {'Product': 'bag',
#   'Name': 'Tahirat',
#   'Rating': '4',
#   'CommentHead': 'bag',
#   'Comment': "It's actually cute and portable. The colour is beautiful. Though there is no lining in it."},
#  {'Product': 'bag',
#   'Name': 'Iniobong',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'Just as seen'},
#  {'Product': 'bag',
#   'Name': 'Ishola Damilare',
#   'Rating': '5',
#   'CommentHead': 'nice',
#   'Comment': 'Good'},
#  {'Product': 'bag',
#   'Name': 'Iheanacho Chile',
#   'Rating': '5',
#   'CommentHead': 'the bag was very nice ',
#   'Comment': 'It came as I expected '},
#  {'Product': 'bag',
#   'Name': 'Jozy Jay',
#   'Rating': '5',
#   'CommentHead': 'looking good ',
#   'Comment': 'Good ???? '},
#  {'Product': 'bag',
#   'Name': 'Faozeeyart',
#   'Rating': '5',
#   'CommentHead': 'nice',
#   'Comment': 'Excellent '},
#  {'Product': 'bag',
#   'Name': 'Lade Paige',
#   'Rating': '4',
#   'CommentHead': 'nice ',
#   'Comment': 'For the price I wasn’t expecting anything more '},
#  {'Product': 'bag',
#   'Name': 'Chioma',
#   'Rating': '5',
#   'CommentHead': 'nice bag',
#   'Comment': 'Nice bag'},
#  {'Product': 'bag',
#   'Name': 'Oyepeju',
#   'Rating': '5',
#   'CommentHead': 'i really like it',
#   'Comment': 'Unique and beautiful bag.'},
#  {'Product': 'bag',
#   'Name': 'Catherine',
#   'Rating': '5',
#   'CommentHead': 'perfect.',
#   'Comment': 'Iove it. '},
#  {'Product': 'bag',
#   'Name': 'Juliet',
#   'Rating': '5',
#   'CommentHead': 'lovely',
#   'Comment': 'Portable Hand Bag '},
#  {'Product': 'bag',
#   'Name': 'elizabethblog',
#   'Rating': '5',
#   'CommentHead': 'beautiful',
#   'Comment': 'I so much love it menhhh'},
#  {'Product': 'bag',
#   'Name': 'Ali Ahmad',
#   'Rating': '5',
#   'CommentHead': 'all',
#   'Comment': 'high quality '},
#  {'Product': 'bag',
#   'Name': 'Olamide',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'It is cute'},
#  {'Product': 'bag',
#   'Name': 'Ada',
#   'Rating': '5',
#   'CommentHead': 'love it..',
#   'Comment': 'Likey Likey!!'},
#  {'Product': 'bag',
#   'Name': 'Adetutu',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'It was a nice bag and last long '},
#  {'Product': 'bag',
#   'Name': 'Sophia',
#   'Rating': '5',
#   'CommentHead': 'nice bag',
#   'Comment': 'Spacious '},
#  {'Product': 'bag',
#   'Name': 'Osaivbie',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'It’s exactly as seen and durable'},
#  {'Product': 'bag',
#   'Name': 'xoxo',
#   'Rating': '2',
#   'CommentHead': 'fair. quality',
#   'Comment': "It's not an everyday bag. It can't carry heavy stuff cos the handle isn't strong "},
#  {'Product': 'bag',
#   'Name': 'Angela',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Satisfactory '},
#  {'Product': 'bag',
#   'Name': 'Chukwuma',
#   'Rating': '3',
#   'CommentHead': 'its not adjustable as should',
#   'Comment': 'It look shorter'},
#  {'Product': 'bag',
#   'Name': 'Mr Rome',
#   'Rating': '3',
#   'CommentHead': 'considerably okay',
#   'Comment': 'Is good but not as I anticipated '},
#  {'Product': 'bag',
#   'Name': 'Peace Ayankoya',
#   'Rating': '5',
#   'CommentHead': 'good',
#   'Comment': 'Good as displayed \n'},
#  {'Product': 'bag',
#   'Name': 'Christianah',
#   'Rating': '4',
#   'CommentHead': 'i like',
#   'Comment': 'The bag is lovely and spacious'},
#  {'Product': 'bag',
#   'Name': 'Omobolanle',
#   'Rating': '3',
#   'CommentHead': 'is good ',
#   'Comment': 'I love it,is very spacious.'},
#  {'Product': 'bag',
#   'Name': 'Amaka',
#   'Rating': '5',
#   'CommentHead': 'beautiful',
#   'Comment': 'Such a pretty little bag. I love it. '},
#  {'Product': 'bag',
#   'Name': 'Eucharia',
#   'Rating': '5',
#   'CommentHead': 'its beautiful',
#   'Comment': "Same color and it's a beautiful mini bag \nMaterial checks out ✔️✅\n"},
#  {'Product': 'bag',
#   'Name': 'Igba Christiana Omolola Igba Christiana Omolola',
#   'Rating': '5',
#   'CommentHead': 'bag is nice',
#   'Comment': 'It’s beautiful '},
#  {'Product': 'bag',
#   'Name': 'Delight',
#   'Rating': '5',
#   'CommentHead': 'beautiful',
#   'Comment': 'Quality and beautiful '},
#  {'Product': 'bag',
#   'Name': 'Tinuola Osewa',
#   'Rating': '5',
#   'CommentHead': 'love it!',
#   'Comment': 'Love love love it. Although the brand name is not on the bag'},
#  {'Product': 'bag',
#   'Name': 'Juliet',
#   'Rating': '4',
#   'CommentHead': 'its nice',
#   'Comment': 'As displayed, light weight and cool'},
#  {'Product': 'bag',
#   'Name': 'Michael',
#   'Rating': '5',
#   'CommentHead': 'mr',
#   'Comment': 'is manageable\n\n'},
#  {'Product': 'bag',
#   'Name': 'Joy',
#   'Rating': '4',
#   'CommentHead': 'as seen',
#   'Comment': 'Good\n'},
#  {'Product': 'bag',
#   'Name': 'Maryann',
#   'Rating': '5',
#   'CommentHead': 'good',
#   'Comment': 'Perfect size'},
#  {'Product': 'bag',
#   'Name': 'Ikenna',
#   'Rating': '5',
#   'CommentHead': 'good',
#   'Comment': "Serves it's purpose perfectly "},
#  {'Product': 'bag',
#   'Name': 'Olamilekan',
#   'Rating': '1',
#   'CommentHead': "i don't like it",
#   'Comment': 'The quality is inferior and the zip got spoil the day I pick up the item'},
#  {'Product': 'bag',
#   'Name': 'ONI-KAYODE',
#   'Rating': '5',
#   'CommentHead': 'very effective',
#   'Comment': 'Thanks a lot for this'},
#  {'Product': 'bag',
#   'Name': 'Okunlade',
#   'Rating': '5',
#   'CommentHead': 'amazing',
#   'Comment': 'Good '},
#  {'Product': 'bag',
#   'Name': 'Mbang',
#   'Rating': '5',
#   'CommentHead': 'i love it!',
#   'Comment': "It's worth the price. Exactly what I ordered for."},
#  {'Product': 'bag',
#   'Name': 'Wilfred',
#   'Rating': '5',
#   'CommentHead': 'good',
#   'Comment': 'Good '},
#  {'Product': 'bag',
#   'Name': 'Franklin',
#   'Rating': '3',
#   'CommentHead': "it's okay",
#   'Comment': 'The bag is good but the zip is not strong mine have remove after (2) two days that I bought it'},
#  {'Product': 'bag',
#   'Name': 'Anita Dike',
#   'Rating': '4',
#   'CommentHead': 'black beautiful bag  ',
#   'Comment': 'It’s good for the price, well the quality it’s nice for the price and I will definitely recommend for ladies .'},
#  {'Product': 'bag',
#   'Name': 'Oluwadunni',
#   'Rating': '5',
#   'CommentHead': 'good quality ',
#   'Comment': 'Good quality. It is worth every penny '},
#  {'Product': 'bag',
#   'Name': 'Amaka',
#   'Rating': '5',
#   'CommentHead': 'beautiful',
#   'Comment': 'Finer than the picture. I love it!'},
#  {'Product': 'bag',
#   'Name': 'Okey ',
#   'Rating': '4',
#   'CommentHead': 'good',
#   'Comment': 'They didn’t include the handle, aside from that good bag.'},
#  {'Product': 'bag',
#   'Name': 'Oyepeju',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'Very beautiful portable bag'},
#  {'Product': 'bag',
#   'Name': 'Oluwadunni',
#   'Rating': '5',
#   'CommentHead': 'good quality',
#   'Comment': 'Worth more than the price '},
#  {'Product': 'bag',
#   'Name': 'Sam',
#   'Rating': '3',
#   'CommentHead': 'it’s okay.',
#   'Comment': 'Just a little smaller than I expected.'},
#  {'Product': 'bag',
#   'Name': 'Olamilekan',
#   'Rating': '4',
#   'CommentHead': 'nice',
#   'Comment': 'Increase the quality '},
#  {'Product': 'bag',
#   'Name': 'Damilola Shobiye',
#   'Rating': '1',
#   'CommentHead': 'bad zip',
#   'Comment': 'The zips got worn out the second day.. it’s just so\nPoor'},
#  {'Product': 'bag',
#   'Name': 'Joseph',
#   'Rating': '1',
#   'CommentHead': "i don't like it",
#   'Comment': 'Low quality material was used, the zipper broke on first day????'},
#  {'Product': 'bag',
#   'Name': 'Precious',
#   'Rating': '3',
#   'CommentHead': 'try better with your quality',
#   'Comment': "The quality of the bag isn't superb "},
#  {'Product': 'bag',
#   'Name': 'Brownies',
#   'Rating': '2',
#   'CommentHead': 'poor product ',
#   'Comment': 'All zip broke upon opening the bag '},
#  {'Product': 'bag',
#   'Name': 'Joseph',
#   'Rating': '5',
#   'CommentHead': 'cool',
#   'Comment': 'Very good '},
#  {'Product': 'bag',
#   'Name': 'Abdullahi',
#   'Rating': '1',
#   'CommentHead': "i don't like it",
#   'Comment': 'The zips are very weak. Got broken just like a broom'},
#  {'Product': 'bag',
#   'Name': 'Muhammad Kabiru',
#   'Rating': '5',
#   'CommentHead': 'normal ',
#   'Comment': 'It is what it is'},
#  {'Product': 'bag',
#   'Name': 'Anyebe',
#   'Rating': '2',
#   'CommentHead': "i don't like it",
#   'Comment': 'Not too good'},
#  {'Product': 'bag',
#   'Name': 'Oriton',
#   'Rating': '3',
#   'CommentHead': 'it was smaller than i expected',
#   'Comment': "The zippers aren't strong and 5hey broke easily. And the power bank isn't working"},
#  {'Product': 'bag',
#   'Name': 'Gbenga',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'Good one and Portable'},
#  {'Product': 'bag',
#   'Name': 'Jasmine',
#   'Rating': '5',
#   'CommentHead': 'love it',
#   'Comment': 'I have the brown already, but I needed the black too. Lovely bag'},
#  {'Product': 'bag',
#   'Name': 'Princess',
#   'Rating': '4',
#   'CommentHead': 'great quality',
#   'Comment': 'The packaging made the straps squeezed. But the quality is very nice. I recommend. But please improve the packaging,'},
#  {'Product': 'bag',
#   'Name': 'Odili',
#   'Rating': '4',
#   'CommentHead': 'nice',
#   'Comment': "It's okay "},
#  {'Product': 'bag',
#   'Name': 'Bajihenan',
#   'Rating': '5',
#   'CommentHead': 'its beautiful ',
#   'Comment': 'What I was hoping for '},
#  {'Product': 'bag',
#   'Name': 'Deyo',
#   'Rating': '5',
#   'CommentHead': 'its lovely',
#   'Comment': 'This is my second buy of the bag. I like it. Serving purpose.\n\n'},
#  {'Product': 'bag',
#   'Name': 'ESTHER',
#   'Rating': '5',
#   'CommentHead': 'love it',
#   'Comment': 'Good quality'},
#  {'Product': 'bag',
#   'Name': 'Mimiwilly',
#   'Rating': '3',
#   'CommentHead': 'poor quality',
#   'Comment': 'Fragile. Might peel off soon'},
#  {'Product': 'bag',
#   'Name': 'Owoeye',
#   'Rating': '5',
#   'CommentHead': 'matos',
#   'Comment': "It's lovely"},
#  {'Product': 'bag',
#   'Name': 'Mr Rome',
#   'Rating': '5',
#   'CommentHead': 'perfect',
#   'Comment': 'My wife loves it '},
#  {'Product': 'bag',
#   'Name': 'Christianah',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'It is spacious and durable'},
#  {'Product': 'bag',
#   'Name': 'Grace Godwin',
#   'Rating': '4',
#   'CommentHead': 'love it ',
#   'Comment': 'Love it ???? '},
#  {'Product': 'bag',
#   'Name': 'Alozie',
#   'Rating': '1',
#   'CommentHead': "i don't like it",
#   'Comment': 'Low quality, everything is inferior, the zip spoilt same day of collection am scared of the hand falling off on my way to work, the later is too poor'},
#  {'Product': 'bag',
#   'Name': 'Augustina',
#   'Rating': '3',
#   'CommentHead': 'fairly alright',
#   'Comment': 'Fabric is very light, not suitable for heavy luggage. '},
#  {'Product': 'bag',
#   'Name': 'Funmi',
#   'Rating': '4',
#   'CommentHead': 'good',
#   'Comment': "Good but zip not strong. Poor quality zipper and its messes up your clothes as it sheds wool(or maybe ratchet as its called). That can be annoying and you'll think 100 times before you carry it out."},
#  {'Product': 'bag',
#   'Name': 'funmi',
#   'Rating': '4',
#   'CommentHead': 'fair enough',
#   'Comment': 'Was bigger than I expected '},
#  {'Product': 'bag',
#   'Name': 'CHINWENDU',
#   'Rating': '5',
#   'CommentHead': 'i like it.',
#   'Comment': 'This is sooo big even bigger than I expected '},
#  {'Product': 'bag',
#   'Name': 'Ebenezer',
#   'Rating': '2',
#   'CommentHead': 'not as quality as expected',
#   'Comment': 'While the design looks okay, the material used for the bag is not much of a good quality as it can easily tear and may not really last long.'},
#  {'Product': 'bag',
#   'Name': 'Ahmed',
#   'Rating': '5',
#   'CommentHead': 'bag ',
#   'Comment': 'I love the products but it just need an increase in size '},
#  {'Product': 'bag',
#   'Name': 'Erinyanga',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Very Portable'},
#  {'Product': 'bag',
#   'Name': 'Reuben',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'the product arrive in good shape and specification'},
#  {'Product': 'bag',
#   'Name': 'Anonymous',
#   'Rating': '2',
#   'CommentHead': 'less quality for less pay',
#   'Comment': 'The material is very light it will tear easily if used frequently'},
#  {'Product': 'bag',
#   'Name': 'Covenant',
#   'Rating': '4',
#   'CommentHead': 'the size',
#   'Comment': 'Enlarge more..it to small..from phone viewing it was bug but getting it was small'},
#  {'Product': 'bag',
#   'Name': 'Nweze',
#   'Rating': '4',
#   'CommentHead': 'the bag is good i love it',
#   'Comment': 'I love it'},
#  {'Product': 'bag',
#   'Name': 'Opeyemi',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'Wonderful'},
#  {'Product': 'bag',
#   'Name': 'Kadri',
#   'Rating': '5',
#   'CommentHead': 'kadri',
#   'Comment': 'The multifonctional aspect of it.'},
#  {'Product': 'bag',
#   'Name': 'Ademilua Risikat Olaiyadunni',
#   'Rating': '1',
#   'CommentHead': 'the lether of the bag is not quality',
#   'Comment': "Make sure you're selling quality not quantity "},
#  {'Product': 'bag',
#   'Name': 'Paul',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': "It's okay"},
#  {'Product': 'bag',
#   'Name': 'Mary',
#   'Rating': '5',
#   'CommentHead': 'nice and cute',
#   'Comment': 'It can carry a laptop, so not that small. Really beautiful bag'},
#  {'Product': 'bag',
#   'Name': 'Mbamalu',
#   'Rating': '4',
#   'CommentHead': 'fashion 4 in 1 piece leather pink hand bag',
#   'Comment': "It's Okay My Mom Likes it and The Quality is Very Good "},
#  {'Product': 'bag',
#   'Name': 'Ezinne',
#   'Rating': '5',
#   'CommentHead': 'cool',
#   'Comment': 'Just as seen'},
#  {'Product': 'bag',
#   'Name': 'Immaculate',
#   'Rating': '5',
#   'CommentHead': 'the color nd the quality',
#   'Comment': 'The bag is fine,I like it '},
#  {'Product': 'bag',
#   'Name': 'Alani',
#   'Rating': '2',
#   'CommentHead': 'beautiful bag',
#   'Comment': 'But smaller than the picture and the long hand of the big bag is very soft, there is tendency it cuts very soon\n'},
#  {'Product': 'bag',
#   'Name': 'Kelvin',
#   'Rating': '4',
#   'CommentHead': 'nice bag',
#   'Comment': 'My customer love it'},
#  {'Product': 'bag',
#   'Name': 'Val',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': "Just as seen. It's so lovely"},
#  {'Product': 'bag',
#   'Name': 'Prince Adeshina Morounranti',
#   'Rating': '3',
#   'CommentHead': 'not packing ',
#   'Comment': 'they are not packing it very well '},
#  {'Product': 'bag',
#   'Name': 'lorenxo',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'Beautiful bag'},
#  {'Product': 'bag',
#   'Name': 'Kehinde',
#   'Rating': '5',
#   'CommentHead': 'good',
#   'Comment': 'the bag is good'},
#  {'Product': 'bag',
#   'Name': 'cachim ',
#   'Rating': '5',
#   'CommentHead': 'my review',
#   'Comment': "It's well Light to carry.\nIt's worth it."},
#  {'Product': 'bag',
#   'Name': 'YUSUPH',
#   'Rating': '1',
#   'CommentHead': "i don't like it at all",
#   'Comment': "The product was small than how it's displayed, and the zip worn out immediately I touch to open it, I never open it at all. It was bad"},
#  {'Product': 'bag',
#   'Name': 'Emmanuel Onipede',
#   'Rating': '3',
#   'CommentHead': 'yes',
#   'Comment': 'The zip was not good I had to change it but asides that it’s good '},
#  {'Product': 'bag',
#   'Name': 'Oladele',
#   'Rating': '2',
#   'CommentHead': "i don't like it",
#   'Comment': 'This is an inferior material'},
#  {'Product': 'bag',
#   'Name': 'Uche Blessing',
#   'Rating': '1',
#   'CommentHead': 'the zip and stitches is not strong',
#   'Comment': 'The zip is a mess. I had to change all the zipper '},
#  {'Product': 'bag',
#   'Name': 'Ado',
#   'Rating': '2',
#   'CommentHead': "i don't like it",
#   'Comment': 'the zipper is terrible'},
#  {'Product': 'bag',
#   'Name': 'Ugochukwu',
#   'Rating': '2',
#   'CommentHead': 'not strong',
#   'Comment': 'Not strong enough '},
#  {'Product': 'bag',
#   'Name': 'mary',
#   'Rating': '3',
#   'CommentHead': 'fine bag ',
#   'Comment': 'I like it '},
#  {'Product': 'bag',
#   'Name': 'Modupe',
#   'Rating': '2',
#   'CommentHead': 'fashion pu fabric',
#   'Comment': 'The material texture is poor and the zips are the first to go within 3 weeks'},
#  {'Product': 'bag',
#   'Name': 'Olashile',
#   'Rating': '2',
#   'CommentHead': 'i don’t like it',
#   'Comment': 'Because it didn’t serve me as long as I wanted until I had to go buy another bag and also the material is not a good one so I don’t like it'},
#  {'Product': 'bag',
#   'Name': 'Benita',
#   'Rating': '4',
#   'CommentHead': 'its okay',
#   'Comment': "It's beautiful but does not have a neat sewing, some places weren't glued properly leaving holes on the bag and it also had stains. But asides that, it's a nice bag"},
#  {'Product': 'bag',
#   'Name': 'Marian',
#   'Rating': '5',
#   'CommentHead': 'nice',
#   'Comment': "I'm enjoying my bag. Contains all my basics. "},
#  {'Product': 'bag',
#   'Name': 'Remii',
#   'Rating': '4',
#   'CommentHead': "it's manageable",
#   'Comment': 'It kinda not very solid'},
#  {'Product': 'bag',
#   'Name': 'Olawale',
#   'Rating': '3',
#   'CommentHead': 'not bad for the price',
#   'Comment': 'The bad is small'},
#  {'Product': 'bag',
#   'Name': 'Stella',
#   'Rating': '5',
#   'CommentHead': 'perfect ',
#   'Comment': 'I got exactly what I ordered '},
#  {'Product': 'bag',
#   'Name': 'Dave',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'It is okay'},
#  {'Product': 'bag',
#   'Name': 'Lysa',
#   'Rating': '3',
#   'CommentHead': 'n/a',
#   'Comment': 'The outside looks like the picture but the inside is not properly finished there is not lining.'},
#  {'Product': 'bag',
#   'Name': 'Emere',
#   'Rating': '3',
#   'CommentHead': 'just ok',
#   'Comment': 'Ok for the price'},
#  {'Product': 'bag',
#   'Name': 'Faozeeyart',
#   'Rating': '3',
#   'CommentHead': 'hand chain',
#   'Comment': 'With leather hand'},
#  {'Product': 'bag',
#   'Name': 'Caleb',
#   'Rating': '5',
#   'CommentHead': 'my babe loves it',
#   'Comment': 'My babe loves it'},
#  {'Product': 'bag',
#   'Name': 'Mary',
#   'Rating': '4',
#   'CommentHead': 'the chain is not what i expected ',
#   'Comment': 'Good'},
#  {'Product': 'bag',
#   'Name': 'Angel',
#   'Rating': '4',
#   'CommentHead': 'okies',
#   'Comment': 'Tho is small oo, chaii, wanted to return it but bcos its very strong and can contain my wallet, 2phones and mini umbrella, I decided to keep it. Wish its a little more bigger ????'},
#  {'Product': 'bag',
#   'Name': 'Peculiar',
#   'Rating': '1',
#   'CommentHead': 'the bag is non strong ',
#   'Comment': 'Material not solid and is non going to last long '},
#  {'Product': 'bag',
#   'Name': 'Oghenemega',
#   'Rating': '2',
#   'CommentHead': 'soft',
#   'Comment': 'Not as good or sturdy as it looks.'},
#  {'Product': 'bag',
#   'Name': 'Emmanuel',
#   'Rating': '4',
#   'CommentHead': 'good ',
#   'Comment': "It's good, but low quality "},
#  {'Product': 'bag',
#   'Name': 'Kay Daniels',
#   'Rating': '5',
#   'CommentHead': 'small but fancy ',
#   'Comment': "If you're the type that likes small stuffs you can go for it. "},
#  {'Product': 'bag',
#   'Name': 'Abiodun',
#   'Rating': '4',
#   'CommentHead': 'zip',
#   'Comment': 'The zip side,it worn out easily. You should try to make it strong and not to worn out easily.'},
#  {'Product': 'bag',
#   'Name': 'Bilyamin Abiola',
#   'Rating': '2',
#   'CommentHead': "i don't like it",
#   'Comment': 'Low quality'},
#  {'Product': 'bag',
#   'Name': 'Joseph',
#   'Rating': '4',
#   'CommentHead': "it's a good product",
#   'Comment': "Though I thought it would be very thick and firm the way it was displayed but it turned out to be a bit lessen in quality than I expected and even the other 2 sets just appeared to be manageable. Anyways, it's usable and that makes it good."},
#  {'Product': 'bag',
#   'Name': 'Inehimughele',
#   'Rating': '1',
#   'CommentHead': 'low quanlity',
#   'Comment': 'Very low quanlity material for that price'},
#  {'Product': 'bag',
#   'Name': 'Reginald',
#   'Rating': '3',
#   'CommentHead': 'okay',
#   'Comment': "It's smaller than expected.\r\nThe two smaller purses are the only pockets in the bag, so once they are out, there are no other places to keep stuff. It has the laptop space inside too."},
#  {'Product': 'bag',
#   'Name': 'Chukwu',
#   'Rating': '3',
#   'CommentHead': 'not satisfied',
#   'Comment': 'The bag is light, very light ????. The quality you have in mind is not what you are going to get. The picture looks appealing ???? but you will get disappointed when you see the actual product. ????'},
#  {'Product': 'bag',
#   'Name': 'Esther',
#   'Rating': '3',
#   'CommentHead': 'beautiful',
#   'Comment': 'Very good product '},
#  {'Product': 'bag',
#   'Name': 'Moses',
#   'Rating': '5',
#   'CommentHead': 'chest bag ',
#   'Comment': 'Excellent\n'},
#  {'Product': 'bag',
#   'Name': 'Judith',
#   'Rating': '1',
#   'CommentHead': 'bag',
#   'Comment': 'It was small and it quality was poor '},
#  {'Product': 'bag',
#   'Name': 'Dah',
#   'Rating': '2',
#   'CommentHead': "it's not as quality as expected",
#   'Comment': 'Zip spoilt on first opening'},
#  {'Product': 'bag',
#   'Name': 'Nasirudeen',
#   'Rating': '2',
#   'CommentHead': 'fair ',
#   'Comment': 'The zips are not good '},
#  {'Product': 'bag',
#   'Name': 'David',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': "It's nice"},
#  {'Product': 'bag',
#   'Name': 'Victoria',
#   'Rating': '1',
#   'CommentHead': 'very bad',
#   'Comment': 'Poor material '},
#  {'Product': 'bag',
#   'Name': 'Olamide',
#   'Rating': '5',
#   'CommentHead': 'very strong',
#   'Comment': 'I like that it has multiple pockets'},
#  {'Product': 'bag',
#   'Name': 'Remember',
#   'Rating': '1',
#   'CommentHead': 'very bad',
#   'Comment': 'Very ???? bad'},
#  {'Product': 'bag',
#   'Name': 'Jonathan',
#   'Rating': '4',
#   'CommentHead': 'its good ',
#   'Comment': 'Exactly what I ordered '},
#  {'Product': 'bag',
#   'Name': 'Mecca',
#   'Rating': '2',
#   'CommentHead': 'casual bag',
#   'Comment': 'The product does not worth the price because of the quality of the material used for the bag .'},
#  {'Product': 'bag',
#   'Name': 'Olufunsho Vic',
#   'Rating': '3',
#   'CommentHead': 'fragile',
#   'Comment': 'Fragile'},
#  {'Product': 'bag',
#   'Name': 'Asaba',
#   'Rating': '4',
#   'CommentHead': 'she like it',
#   'Comment': 'Got what I ordered for.'},
#  {'Product': 'bag',
#   'Name': 'Faith',
#   'Rating': '5',
#   'CommentHead': 'perfect',
#   'Comment': 'Just as seen'},
#  {'Product': 'bag',
#   'Name': 'Omaobi Emenike',
#   'Rating': '5',
#   'CommentHead': 'quality is top notch ',
#   'Comment': 'The quality \nIt’s worth the price '},
#  {'Product': 'bag',
#   'Name': 'Modester',
#   'Rating': '4',
#   'CommentHead': 'good bag',
#   'Comment': "Please increase the space in the bag, the design is very beautiful but the bag doesn't have enough space"},
#  {'Product': 'bag',
#   'Name': 'Favour',
#   'Rating': '4',
#   'CommentHead': 'just ok ',
#   'Comment': "The bag is beautiful but the space isn't big"},
#  {'Product': 'bag',
#   'Name': 'Kehinde Oguntuashe',
#   'Rating': '5',
#   'CommentHead': 'excellent',
#   'Comment': 'Exactly what I expected ????'},
#  {'Product': 'bag',
#   'Name': 'Didekemie',
#   'Rating': '4',
#   'CommentHead': 'good bag',
#   'Comment': 'Good bag'},
#  {'Product': 'bag',
#   'Name': 'Dioma',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Just as I expected. Really impressed'},
#  {'Product': 'bag',
#   'Name': 'Efosa Gregory',
#   'Rating': '5',
#   'CommentHead': 'so beautiful',
#   'Comment': 'The best bag I have bought here in Jumia so far'},
#  {'Product': 'bag',
#   'Name': 'Aderemi Ezekiel',
#   'Rating': '3',
#   'CommentHead': 'ok',
#   'Comment': 'Yeah it could be better'},
#  {'Product': 'bag',
#   'Name': 'Evelyn',
#   'Rating': '2',
#   'CommentHead': 'just ok',
#   'Comment': 'It cannot carry a laptop and that was the main attraction so I cant use it'},
#  {'Product': 'bag',
#   'Name': 'Asenath',
#   'Rating': '4',
#   'CommentHead': 'bag',
#   'Comment': 'Bigger than what was display mummy’s bag cos of the size but I still love the bag '},
#  {'Product': 'bag',
#   'Name': 'Olamide',
#   'Rating': '4',
#   'CommentHead': 'i like it',
#   'Comment': 'The bag is superb'},
#  {'Product': 'bag',
#   'Name': 'Mo',
#   'Rating': '4',
#   'CommentHead': "it's good.",
#   'Comment': "My sister liked it. I wish the inner lining was made of a silky material to give it that luxurious feel. All in all, it's a great buy."},
#  {'Product': 'bag',
#   'Name': 'kingsley',
#   'Rating': '5',
#   'CommentHead': 'the bag is okay',
#   'Comment': 'Same as requested \nVery okay'},
#  {'Product': 'bag',
#   'Name': 'Nkem',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Exactly as seen in the picture and it came right on time.'},
#  {'Product': 'bag',
#   'Name': 'Abigail',
#   'Rating': '4',
#   'CommentHead': "it's good",
#   'Comment': 'I like it '},
#  {'Product': 'bag',
#   'Name': 'Tina',
#   'Rating': '4',
#   'CommentHead': 'bag',
#   'Comment': "It's OK . Looks good. I like it"},
#  {'Product': 'bag',
#   'Name': 'Nkechi',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'it is, as described'},
#  {'Product': 'bag',
#   'Name': 'Julie',
#   'Rating': '5',
#   'CommentHead': 'i love it',
#   'Comment': 'Just as displayed, it is very beautiful and big\n'},
#  {'Product': 'bag',
#   'Name': 'Julius',
#   'Rating': '5',
#   'CommentHead': 'it is perfect',
#   'Comment': 'It is perfect, just as described. Thumb up '},
#  {'Product': 'bag',
#   'Name': 'JOHN',
#   'Rating': '5',
#   'CommentHead': 'excellent bag',
#   'Comment': 'She loved it. Thank you'},
#  {'Product': 'bag',
#   'Name': 'GRACE',
#   'Rating': '1',
#   'CommentHead': 'poor. quality',
#   'Comment': "The zipper spoilt same day, can't use it"},
#  {'Product': 'bag',
#   'Name': 'Stephen',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'I got what i ordered, nice purchase!'},
#  {'Product': 'bag',
#   'Name': 'Berry',
#   'Rating': '5',
#   'CommentHead': 'nice gift',
#   'Comment': "It's good to carry along, I like it"},
#  {'Product': 'bag',
#   'Name': 'Ahman Ibrahim',
#   'Rating': '5',
#   'CommentHead': 'good!',
#   'Comment': 'Very durable and good quality '},
#  {'Product': 'bag',
#   'Name': 'Matthew Samuel',
#   'Rating': '5',
#   'CommentHead': 'great ',
#   'Comment': 'I love it, exactly what I ordered. Thanks a lot. '},
#  {'Product': 'bag',
#   'Name': 'Dê Brãvē',
#   'Rating': '5',
#   'CommentHead': 'excellent choice',
#   'Comment': "It's a great bag, I got it just the way I ordered it.,.very durable and excellent foy your laptop and other personal stuffs..."},
#  {'Product': 'bag',
#   'Name': 'Aubin',
#   'Rating': '5',
#   'CommentHead': 'perfect',
#   'Comment': 'i appreciate it'},
#  {'Product': 'bag',
#   'Name': 'Mariam',
#   'Rating': '5',
#   'CommentHead': 'good and durable',
#   'Comment': 'it seems strong and I love that it has a USB connector  that can be connected to a power bank to charge your device when on the move'},
#  {'Product': 'bag',
#   'Name': 'Promise Friday',
#   'Rating': '5',
#   'CommentHead': 'good stuff ',
#   'Comment': 'Strong and reliable '},
#  {'Product': 'bag',
#   'Name': 'Onuche',
#   'Rating': '4',
#   'CommentHead': 'good',
#   'Comment': 'Surprisingly of good quality.'},
#  {'Product': 'bag',
#   'Name': 'Micah',
#   'Rating': '3',
#   'CommentHead': 'not spacious',
#   'Comment': 'not as spacious as it looked'},
#  {'Product': 'bag',
#   'Name': 'Anjola Oluwaleye',
#   'Rating': '5',
#   'CommentHead': 'really nice ',
#   'Comment': 'Loved this '},
#  {'Product': 'bag',
#   'Name': 'Duman',
#   'Rating': '5',
#   'CommentHead': 'i like it',
#   'Comment': 'Perfect'},
#  {'Product': 'bag',
#   'Name': 'Tinuola Osewa',
#   'Rating': '5',
#   'CommentHead': 'amazing',
#   'Comment': 'Love it'},
#  {'Product': 'bag',
#   'Name': 'Bolaji Michaels',
#   'Rating': '5',
#   'CommentHead': 'lovely ',
#   'Comment': 'Lovely '},
#  {'Product': 'bag',
#   'Name': 'Rosemary',
#   'Rating': '3',
#   'CommentHead': 'it okay',
#   'Comment': 'Sorry My Defecto;but this one did really meet my expectations, The body of the is a little bit soft or too light; yeah.Not what I imagine, but am enjoying anyways.Thanks Defecto '},
#  {'Product': 'bag',
#   'Name': 'Guest',
#   'Rating': '5',
#   'CommentHead': 'good',
#   'Comment': 'The bag is very okay and spacious. Good purchase'},
#  {'Product': 'bag',
#   'Name': 'Tomi',
#   'Rating': '2',
#   'CommentHead': 'poor quality',
#   'Comment': 'You can only use it to carry tissue papers'},
#  {'Product': 'bag',
#   'Name': 'Bolaji Michaels',
#   'Rating': '5',
#   'CommentHead': 'lovely ',
#   'Comment': 'Lovely '}]
